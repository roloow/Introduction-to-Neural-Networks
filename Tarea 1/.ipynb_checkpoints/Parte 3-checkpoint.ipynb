# %% [markdown]
# # Código y trabajo
#
# Parte 3
# -----

# %% [markdown]
# a)
# --

# %%
import pandas as pd
from sklearn.cross_validation import train_test_split

url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/housing/housing.data'
df = pd.read_csv(url, sep='\s+', header=None, names=['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV'])
df_train, df_test = train_test_split(df, test_size=0.2, random_state=0)
df.shape
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
# CRIM       506 non-null float64
# ZN         506 non-null float64
# INDUS      506 non-null float64
# CHAS       506 non-null int64
# NOX        506 non-null float64
# RM         506 non-null float64
# AGE        506 non-null float64
# DIS        506 non-null float64
# RAD        506 non-null int64
# TAX        506 non-null float64
# PTRATIO    506 non-null float64
# B          506 non-null float64
# LSTAT      506 non-null float64
# MEDV       506 non-null float64
# dtypes: float64(12), int64(2)
# memory usage: 55.4 KB
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# ...

# %% [markdown]
# El dataset a utilizar es un archivo con 506 distitos datos, separados con 14 distitas características. Se puede observar en la tabla mostrada anteriormente un resumen de los distintos valores estadísticos de cada una de las columnas para todos los valores.

# %% [markdown]
# b)
# --

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler().fit(df_train)
X_train_scaled = pd.DataFrame(scaler.transform(df_train), columns=df_train.columns)
y_train_scaled = df_train.pop('MEDV')

# %%
X_test_scaled = pd.DataFrame(scaler.transform(df_test), columns=df_test.columns)
y_test_scaled = df_test.pop('MEDV')

# %% [markdown]
# Claramente la normalizacion de los datos es absolutamente necesaria. Se puede ver en el resumen del dataset a usar que hay valores muy distintos, donde en algunos el promedio es 408.237 y en otros el promedio es 0.5546
# Si no se normalizaran los datos, estos no se podrían utilizar para sacar conclusiones certeras.

# %% [markdown]
# c)
# --

# %%
from keras.models import Sequential
from keras.layers.core import Dense, Activation
from keras.optimizers import SGD
import matplotlib.pyplot as plt

model = Sequential()
model.add(Dense(200, input_dim=X_train_scaled.shape[1], init='uniform'))
model.add(Activation('sigmoid'))
model.add(Dense(1, init='uniform'))
model.add(Activation('linear'))

sgd = SGD(lr=0.01)
model.compile(optimizer=sgd, loss='mean_squared_error')

hist = model.fit(X_train_scaled.as_matrix(), y_train_scaled.as_matrix(), nb_epoch=300, verbose=1, validation_data=(X_test_scaled.as_matrix(), y_test_scaled.as_matrix()))
# Out:
# Using TensorFlow backend.
# /Users/ricardocarrasco/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:7: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(200, kernel_initializer="uniform", input_dim=14)`
# /Users/ricardocarrasco/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:9: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(1, kernel_initializer="uniform")`
# /Users/ricardocarrasco/anaconda/lib/python2.7/site-packages/keras/models.py:834: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   warnings.warn('The `nb_epoch` argument in `fit` '
# Train on 404 samples, validate on 102 samples
# Epoch 1/300
# 404/404 [==============================] - 0s - loss: 102.3259 - val_loss: 44.0184
# Epoch 2/300
# 404/404 [==============================] - 0s - loss: 27.4214 - val_loss: 34.6284
# Epoch 3/300
# 404/404 [==============================] - 0s - loss: 20.0463 - val_loss: 28.7400
# Epoch 4/300
# ...

# %%
import matplotlib.pyplot as plt
plt.xlabel("Epoch")
plt.ylabel("MSE")
plt.plot(hist.epoch, hist.history['loss'])
plt.grid(True)
plt.show()
print(min(hist.history['loss']))
# Out:
# 0.0849687063163

# %% [markdown]
# Claramente se puede observar que hay una convergencia, esto se ve en el nivel de pérdida, partiendo con un valor superior a 99 llegando a un nivel de pérdida de 0.0840, lo cual demuestra claramente la convergencia del entrenamiento (estos valores cambian dependiendo del aprendizaje en específico que se tenga).

# %% [markdown]
# d)
# --

# %%
model = Sequential()
model.add(Dense(200, input_dim=X_train_scaled.shape[1], init='uniform'))
model.add(Activation('relu'))
model.add(Dense(1, init='uniform'))
model.add(Activation('linear'))

sgd = SGD(lr=0.01)
model.compile(optimizer=sgd, loss='mean_squared_error')

hist = model.fit(X_train_scaled.as_matrix(), y_train_scaled.as_matrix(), nb_epoch=300, verbose=1, validation_data=(X_test_scaled.as_matrix(), y_test_scaled.as_matrix()))
# Out:
# /Users/ricardocarrasco/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(200, kernel_initializer="uniform", input_dim=14)`
#   from ipykernel import kernelapp as app
# /Users/ricardocarrasco/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:4: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(1, kernel_initializer="uniform")`
# Train on 404 samples, validate on 102 samples
# Epoch 1/300
# 404/404 [==============================] - 0s - loss: 237.6753 - val_loss: 35.0852
# Epoch 2/300
# 404/404 [==============================] - 0s - loss: 13.3122 - val_loss: 11.6899
# Epoch 3/300
# 404/404 [==============================] - 0s - loss: 5.8175 - val_loss: 7.1238
# Epoch 4/300
# 404/404 [==============================] - 0s - loss: 3.1032 - val_loss: 5.8145
# Epoch 5/300
# 404/404 [==============================] - 0s - loss: 2.2347 - val_loss: 3.3900
# Epoch 6/300
# ...

# %%
import matplotlib.pyplot as plt
print(min(hist.history['loss']))
plt.xlabel("Epoch")
plt.ylabel("MSE")
plt.plot(hist.epoch, hist.history['loss'])
plt.grid(True)
plt.show()
# Out:
# 0.00403949295373

# %% [markdown]
# Para este caso también se observa una convergencia, la cual es extramadamente rápida y converge a un valor muy cercano a cero (en este caso de prueba a 0.00461)

# %% [markdown]
# e)
# --

# %%
import numpy as np
import random

n_lr = 20
learn_rate = np.linspace(0,0.01,n_lr)

# %%
model = Sequential()
model.add(Dense(200, input_dim=X_train_scaled.shape[1], init='uniform'))
model.add(Activation('sigmoid'))
model.add(Dense(1, init='uniform'))
model.add(Activation('linear'))

for i in range(n_lr):
    print list(learn_rate)[i]
    sgd = SGD(lr=list(learn_rate)[i])
    model.compile(optimizer=sgd, loss='mean_squared_error')
    hist = model.fit(X_train_scaled.as_matrix(), y_train_scaled.as_matrix(), nb_epoch=20, verbose=1, validation_data=(X_test_scaled.as_matrix(), y_test_scaled.as_matrix()))
    print(min(hist.history['loss']))
    plt.xlabel("Epoch")
    plt.ylabel("MSE")
    plt.plot(hist.epoch, hist.history['loss'])
    plt.grid(True)
    plt.show()
# Out:
# /Users/ricardocarrasco/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(200, kernel_initializer="uniform", input_dim=14)`
#   from ipykernel import kernelapp as app
# /Users/ricardocarrasco/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:4: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(1, kernel_initializer="uniform")`
# 0.0
# Train on 404 samples, validate on 102 samples
# Epoch 1/20
# 404/404 [==============================] - 0s - loss: 589.2036 - val_loss: 568.0464
# Epoch 2/20
# 404/404 [==============================] - 0s - loss: 589.2036 - val_loss: 568.0464
# Epoch 3/20
# 404/404 [==============================] - 0s - loss: 589.2036 - val_loss: 568.0464
# Epoch 4/20
# 404/404 [==============================] - 0s - loss: 589.2036 - val_loss: 568.0464
# Epoch 5/20
# 404/404 [==============================] - 0s - loss: 589.2036 - val_loss: 568.0464
# Epoch 6/20
# ...

# %% [markdown]
# Se puede ver que comienza a converger de manera más suave lentamente.

# %%
model = Sequential()
model.add(Dense(200, input_dim=X_train_scaled.shape[1], init='uniform'))
model.add(Activation('relu'))
model.add(Dense(1, init='uniform'))
model.add(Activation('linear'))

for i in range(n_lr):
    print list(learn_rate)[i]
    sgd = SGD(lr=list(learn_rate)[i])
    model.compile(optimizer=sgd, loss='mean_squared_error')
    hist = model.fit(X_train_scaled.as_matrix(), y_train_scaled.as_matrix(), nb_epoch=20, verbose=1, validation_data=(X_test_scaled.as_matrix(), y_test_scaled.as_matrix()))
    print(min(hist.history['loss']))
    plt.xlabel("Epoch")
    plt.ylabel("MSE")
    plt.plot(hist.epoch, hist.history['loss'])
    plt.grid(True)
    plt.show()
# Out:
# /Users/ricardocarrasco/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(200, kernel_initializer="uniform", input_dim=14)`
#   from ipykernel import kernelapp as app
# /Users/ricardocarrasco/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:4: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(1, kernel_initializer="uniform")`
# 0.0
# Train on 404 samples, validate on 102 samples
# Epoch 1/20
# 404/404 [==============================] - 0s - loss: 597.0798 - val_loss: 575.5341
# Epoch 2/20
# 404/404 [==============================] - 0s - loss: 597.0798 - val_loss: 575.5341
# Epoch 3/20
# 404/404 [==============================] - 0s - loss: 597.0798 - val_loss: 575.5341
# Epoch 4/20
# 404/404 [==============================] - 0s - loss: 597.0798 - val_loss: 575.5341
# Epoch 5/20
# 404/404 [==============================] - 0s - loss: 597.0798 - val_loss: 575.5341
# Epoch 6/20
# ...

# %% [markdown]
# f)
# --

# %%
from sklearn import cross_validation
import numpy as np
K=5
Xm = X_train_scaled.as_matrix()
ym = y_train_scaled.as_matrix()
kfold = cross_validation.KFold(len(Xm),K)
cvscores = []

for i, (train,val) in enumerate(kfold):
    model = Sequential()
    model.add(Dense(200, input_dim=X_train_scaled.shape[1], kernel_initializer='uniform'))
    model.add(Activation('relu'))
    model.add(Dense(1, init='uniform'))
    model.add(Activation('linear'))
    
    sgd = SGD(lr=0.01)
    model.compile(optimizer=sgd, loss='mean_squared_error')
    
    model.fit(Xm[train], ym[train], nb_epoch=30)
    
    scores = model.evaluate(Xm[val], ym[val])
    cvscores.append(scores)
mse_cv = np.mean(cvscores)
# Out:
# /Users/ricardocarrasco/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:13: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(1, kernel_initializer="uniform")`
# Epoch 1/30
# 323/323 [==============================] - 0s - loss: 298.2542
# Epoch 2/30
# 323/323 [==============================] - 0s - loss: 17.8374
# Epoch 3/30
# 323/323 [==============================] - 0s - loss: 8.5663
# Epoch 4/30
# 323/323 [==============================] - 0s - loss: 5.8658
# Epoch 5/30
# 323/323 [==============================] - 0s - loss: 5.1144
# Epoch 6/30
# 323/323 [==============================] - 0s - loss: 4.4078
# Epoch 7/30
# 323/323 [==============================] - 0s - loss: 2.4472
# Epoch 8/30
# 323/323 [==============================] - 0s - loss: 2.2213
# Epoch 9/30
# 323/323 [==============================] - 0s - loss: 1.6132
# Epoch 10/30
# 323/323 [==============================] - 0s - loss: 2.0976
# Epoch 11/30
# ...

# %%
K=10
Xm = X_train_scaled.as_matrix()
ym = y_train_scaled.as_matrix()
kfold = cross_validation.KFold(len(Xm),K)
cvscores = []

for i, (train,val) in enumerate(kfold):
    model = Sequential()
    model.add(Dense(200, input_dim=X_train_scaled.shape[1], kernel_initializer='uniform'))
    model.add(Activation('relu'))
    model.add(Dense(1, init='uniform'))
    model.add(Activation('linear'))
    
    sgd = SGD(lr=0.01)
    model.compile(optimizer=sgd, loss='mean_squared_error')
    
    model.fit(Xm[train], ym[train], nb_epoch=30)
    
    scores = model.evaluate(Xm[val], ym[val])
    cvscores.append(scores)
mse_cv = np.mean(cvscores)
# Out:
# /Users/ricardocarrasco/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:11: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(1, kernel_initializer="uniform")`
# Epoch 1/30
# 363/363 [==============================] - 0s - loss: 269.9183
# Epoch 2/30
# 363/363 [==============================] - 0s - loss: 14.9268
# Epoch 3/30
# 363/363 [==============================] - 0s - loss: 6.4040
# Epoch 4/30
# 363/363 [==============================] - 0s - loss: 3.6692
# Epoch 5/30
# 363/363 [==============================] - 0s - loss: 2.6132
# Epoch 6/30
# 363/363 [==============================] - 0s - loss: 1.7444
# Epoch 7/30
# 363/363 [==============================] - 0s - loss: 1.3240
# Epoch 8/30
# 363/363 [==============================] - 0s - loss: 1.1168
# Epoch 9/30
# 363/363 [==============================] - 0s - loss: 0.9140
# Epoch 10/30
# 363/363 [==============================] - 0s - loss: 0.8493
# Epoch 11/30
# ...

# %% [markdown]
# Usando kfold no es posible ver una mejora en la convergencia de la función

# %% [markdown]
# g)
# --

# %%
n_decay = 0.3
lear_decay = np.logspace(-6,0,n_decay)
sgd = SGD(lr=0.02, decay=1e-6)

# %%
model = Sequential()
model.add(Dense(200, input_dim=X_train_scaled.shape[1], init='uniform'))
model.add(Activation('sigmoid'))
model.add(Dense(1, init='uniform'))
model.add(Activation('linear'))

model.compile(optimizer=sgd, loss='mean_squared_error')

hist = model.fit(X_train_scaled.as_matrix(), y_train_scaled.as_matrix(), nb_epoch=300, verbose=1, validation_data=(X_test_scaled.as_matrix(), y_test_scaled.as_matrix()))
# Out:
# /Users/ricardocarrasco/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(200, kernel_initializer="uniform", input_dim=14)`
#   from ipykernel import kernelapp as app
# /Users/ricardocarrasco/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:4: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(1, kernel_initializer="uniform")`
# Train on 404 samples, validate on 102 samples
# Epoch 1/300
# 404/404 [==============================] - 0s - loss: 675.0737 - val_loss: 84.9149
# Epoch 2/300
# 404/404 [==============================] - 0s - loss: 37.8487 - val_loss: 27.5630
# Epoch 3/300
# 404/404 [==============================] - 0s - loss: 14.1515 - val_loss: 18.2015
# Epoch 4/300
#  - 0s - loss: 8.6539 - val_loss: 13.2678
# Epoch 5/300
# 404/404 [==============================] - 0s - loss: 8.5880 - val_loss: 22.0626
# Epoch 6/300
# ...

# %%
print(min(hist.history['loss']))
plt.xlabel("Epoch")
plt.ylabel("MSE")
plt.plot(hist.epoch, hist.history['loss'])
plt.grid(True)
plt.show()
# Out:
# 0.0915986233123

# %% [markdown]
# Converge de forma muy rápida, similar al caso en c.

# %%
model = Sequential()
model.add(Dense(200, input_dim=X_train_scaled.shape[1], init='uniform'))
model.add(Activation('relu'))
model.add(Dense(1, init='uniform'))
model.add(Activation('linear'))

model.compile(optimizer=sgd, loss='mean_squared_error')

hist = model.fit(X_train_scaled.as_matrix(), y_train_scaled.as_matrix(), nb_epoch=300, verbose=1, validation_data=(X_test_scaled.as_matrix(), y_test_scaled.as_matrix()))
# Out:
# /Users/ricardocarrasco/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(200, kernel_initializer="uniform", input_dim=14)`
#   from ipykernel import kernelapp as app
# /Users/ricardocarrasco/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:4: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(1, kernel_initializer="uniform")`
# Train on 404 samples, validate on 102 samples
# Epoch 1/300
# 404/404 [==============================] - 0s - loss: 65994252.5787 - val_loss: 108203641125214120574976.0000
# Epoch 2/300
# 404/404 [==============================] - 0s - loss: nan - val_loss: nan
# Epoch 3/300
# 404/404 [==============================] - 0s - loss: nan - val_loss: nan
# Epoch 4/300
# 404/404 [==============================] - 0s - loss: nan - val_loss: nan
# Epoch 5/300
# 404/404 [==============================] - 0s - loss: nan - val_loss: nan
# Epoch 6/300
# ...

# %%
print(min(hist.history['loss']))
plt.xlabel("Epoch")
plt.ylabel("MSE")
plt.plot(hist.epoch, hist.history['loss'])
plt.grid(True)
plt.show()
# Out:
# 65994252.5787

# %% [markdown]
# El resultado usando relu diverge.

# %% [markdown]
# h)
# --

# %%
n_decay = 21
momentum = np.linspace(0,1,n_decay)
sgd=SGD(lr=0.01,momentum=0.6)

# %%
model = Sequential()
model.add(Dense(200, input_dim=X_train_scaled.shape[1], init='uniform'))
model.add(Activation('sigmoid'))
model.add(Dense(1, init='uniform'))
model.add(Activation('linear'))

model.compile(optimizer=sgd, loss='mean_squared_error')

hist = model.fit(X_train_scaled.as_matrix(), y_train_scaled.as_matrix(), nb_epoch=300, verbose=1, validation_data=(X_test_scaled.as_matrix(), y_test_scaled.as_matrix()))
# Out:
# /Users/ricardocarrasco/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(200, kernel_initializer="uniform", input_dim=14)`
#   from ipykernel import kernelapp as app
# /Users/ricardocarrasco/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:4: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(1, kernel_initializer="uniform")`
# Train on 404 samples, validate on 102 samples
# Epoch 1/300
# 404/404 [==============================] - 0s - loss: 122.9676 - val_loss: 31.8554
# Epoch 2/300
# 404/404 [==============================] - 0s - loss: 21.0736 - val_loss: 20.1630
# Epoch 3/300
# 404/404 [==============================] - 0s - loss: 11.2362 - val_loss: 14.7624
# Epoch 4/300
# 404/404 [==============================] - 0s - loss: 9.0126 - val_loss: 11.2371
# Epoch 5/300
# 404/404 [==============================] - 0s - loss: 8.3411 - val_loss: 9.6903
# Epoch 6/300
# ...

# %%
import matplotlib.pyplot as plt
print(min(hist.history['loss']))
plt.xlabel("Epoch")
plt.ylabel("MSE")
plt.plot(hist.epoch, hist.history['loss'])
plt.grid(True)
plt.show()
# Out:
# 0.0446488926611

# %% [markdown]
# El resultado final que se observa es similar al observado en el punto c, viendo una convergencia de forma constante pero más rápida que en c.

# %%
model = Sequential()
model.add(Dense(200, input_dim=X_train_scaled.shape[1], init='uniform'))
model.add(Activation('relu'))
model.add(Dense(1, init='uniform'))
model.add(Activation('linear'))

model.compile(optimizer=sgd, loss='mean_squared_error')

hist = model.fit(X_train_scaled.as_matrix(), y_train_scaled.as_matrix(), nb_epoch=300, verbose=1, validation_data=(X_test_scaled.as_matrix(), y_test_scaled.as_matrix()))
# Out:
# /Users/ricardocarrasco/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(200, kernel_initializer="uniform", input_dim=14)`
#   from ipykernel import kernelapp as app
# /Users/ricardocarrasco/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:4: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(1, kernel_initializer="uniform")`
# Train on 404 samples, validate on 102 samples
# Epoch 1/300
# 404/404 [==============================] - 0s - loss: nan - val_loss: nan
# Epoch 2/300
# 404/404 [==============================] - 0s - loss: nan - val_loss: nan
# Epoch 3/300
# 404/404 [==============================] - 0s - loss: nan - val_loss: nan
# Epoch 4/300
# 404/404 [==============================] - 0s - loss: nan - val_loss: nan
# Epoch 5/300
# 404/404 [==============================] - 0s - loss: nan - val_loss: nan
# Epoch 6/300
# ...

# %% [markdown]
# Se puede notar claramente que el resultado diverge.

# %%
model = Sequential()
model.add(Dense(200, input_dim=X_train_scaled.shape[1], init='uniform'))
model.add(Activation('sigmoid'))
model.add(Dense(1, init='uniform'))
model.add(Activation('linear'))

model.compile(optimizer=sgd, loss='mean_squared_error',nesterov=True)

hist = model.fit(X_train_scaled.as_matrix(), y_train_scaled.as_matrix(), nb_epoch=300, verbose=1, validation_data=(X_test_scaled.as_matrix(), y_test_scaled.as_matrix()))
# Out:
# /Users/ricardocarrasco/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(200, kernel_initializer="uniform", input_dim=14)`
#   from ipykernel import kernelapp as app
# /Users/ricardocarrasco/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:4: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(1, kernel_initializer="uniform")`
# /Users/ricardocarrasco/anaconda/lib/python2.7/site-packages/keras/backend/tensorflow_backend.py:2124: UserWarning: Expected no kwargs, you passed 1
# kwargs passed to function are ignored with Tensorflow backend
#   warnings.warn('\n'.join(msg))
# Train on 404 samples, validate on 102 samples
# Epoch 1/300
# 404/404 [==============================] - 0s - loss: 308.2149 - val_loss: 88.3666
# Epoch 2/300
# 404/404 [==============================] - 0s - loss: 63.1456 - val_loss: 57.4756
# Epoch 3/300
# ...

# %%
model = Sequential()
model.add(Dense(200, input_dim=X_train_scaled.shape[1], init='uniform'))
model.add(Activation('relu'))
model.add(Dense(1, init='uniform'))
model.add(Activation('linear'))

model.compile(optimizer=sgd, loss='mean_squared_error',nesterov=True)

hist = model.fit(X_train_scaled.as_matrix(), y_train_scaled.as_matrix(), nb_epoch=300, verbose=1, validation_data=(X_test_scaled.as_matrix(), y_test_scaled.as_matrix()))
# Out:
# /Users/ricardocarrasco/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(200, kernel_initializer="uniform", input_dim=14)`
#   from ipykernel import kernelapp as app
# /Users/ricardocarrasco/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:4: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(1, kernel_initializer="uniform")`
# Train on 404 samples, validate on 102 samples
# Epoch 1/300
# 404/404 [==============================] - 0s - loss: inf - val_loss: nan
# Epoch 2/300
# 404/404 [==============================] - 0s - loss: nan - val_loss: nan
# Epoch 3/300
# 404/404 [==============================] - 0s - loss: nan - val_loss: nan
# Epoch 4/300
# 404/404 [==============================] - 0s - loss: nan - val_loss: nan
# Epoch 5/300
# 404/404 [==============================] - 0s - loss: nan - val_loss: nan
# Epoch 6/300
# ...

# %% [markdown]
# i)
# --

# %%
n_batches = 21
batch_sizes = np.round(np.linspace(1,X_train_scaled.shape[0],n_batches))

# %% [markdown]
# c- con tamaño de batch 50.
# --

# %%
model = Sequential()
model.add(Dense(200, input_dim=X_train_scaled.shape[1], init='uniform'))
model.add(Activation('sigmoid'))
model.add(Dense(1, init='uniform'))
model.add(Activation('linear'))

model.compile(optimizer=sgd, loss='mean_squared_error')

hist = model.fit(X_train_scaled.as_matrix(),y_train_scaled.as_matrix(),batch_size=50,nb_epoch=300)
# Out:
# /Users/ricardocarrasco/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(200, kernel_initializer="uniform", input_dim=14)`
#   from ipykernel import kernelapp as app
# /Users/ricardocarrasco/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:4: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(1, kernel_initializer="uniform")`
# Epoch 1/300
# 404/404 [==============================] - 0s - loss: 164.6889
# Epoch 2/300
# 404/404 [==============================] - 0s - loss: 23.3997
# Epoch 3/300
# 404/404 [==============================] - 0s - loss: 14.4751
# Epoch 4/300
# 404/404 [==============================] - 0s - loss: 12.1958
# Epoch 5/300
# 404/404 [==============================] - 0s - loss: 9.8801
# Epoch 6/300
# 404/404 [==============================] - 0s - loss: 7.5251
# Epoch 7/300
# 404/404 [==============================] - 0s - loss: 6.6128
# Epoch 8/300
# ...

# %%
print(min(hist.history['loss']))
plt.xlabel("Epoch")
plt.ylabel("MSE")
plt.plot(hist.epoch, hist.history['loss'])
plt.grid(True)
plt.show()
# Out:
# 0.0678794214797

# %% [markdown]
# c- con tamaño de batch 100
# --

# %%
model = Sequential()
model.add(Dense(200, input_dim=X_train_scaled.shape[1], init='uniform'))
model.add(Activation('sigmoid'))
model.add(Dense(1, init='uniform'))
model.add(Activation('linear'))

model.compile(optimizer=sgd, loss='mean_squared_error')

hist = model.fit(X_train_scaled.as_matrix(),y_train_scaled.as_matrix(),batch_size=100,nb_epoch=300)
# Out:
# /Users/ricardocarrasco/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(200, kernel_initializer="uniform", input_dim=14)`
#   from ipykernel import kernelapp as app
# /Users/ricardocarrasco/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:4: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(1, kernel_initializer="uniform")`
# Epoch 1/300
# 404/404 [==============================] - 0s - loss: 266.9657
# Epoch 2/300
# 404/404 [==============================] - 0s - loss: 56.6788
# Epoch 3/300
# 404/404 [==============================] - 0s - loss: 24.1296
# Epoch 4/300
# 404/404 [==============================] - 0s - loss: 23.3400
# Epoch 5/300
# 404/404 [==============================] - 0s - loss: 22.2194
# Epoch 6/300
# 404/404 [==============================] - 0s - loss: 11.8631
# Epoch 7/300
# 404/404 [==============================] - 0s - loss: 20.5254
# Epoch 8/300
# ...

# %%
print(min(hist.history['loss']))
plt.xlabel("Epoch")
plt.ylabel("MSE")
plt.plot(hist.epoch, hist.history['loss'])
plt.grid(True)
plt.show()
# Out:
# 0.118295969939

# %% [markdown]
# d- con tamaño de batch 50
# --

# %%
model = Sequential()
model.add(Dense(200, input_dim=X_train_scaled.shape[1], init='uniform'))
model.add(Activation('relu'))
model.add(Dense(1, init='uniform'))
model.add(Activation('linear'))

model.compile(optimizer=sgd, loss='mean_squared_error')

model.fit(X_train_scaled.as_matrix(),y_train_scaled.as_matrix(),batch_size=50,nb_epoch=300)
# Out:
# /Users/ricardocarrasco/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(200, kernel_initializer="uniform", input_dim=14)`
#   from ipykernel import kernelapp as app
# /Users/ricardocarrasco/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:4: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(1, kernel_initializer="uniform")`
# Epoch 1/300
# 404/404 [==============================] - 0s - loss: nan
# Epoch 2/300
# 404/404 [==============================] - 0s - loss: nan
# Epoch 3/300
# 404/404 [==============================] - 0s - loss: nan
# Epoch 4/300
# 404/404 [==============================] - 0s - loss: nan
# Epoch 5/300
# 404/404 [==============================] - 0s - loss: nan
# Epoch 6/300
# 404/404 [==============================] - 0s - loss: nan
# Epoch 7/300
# 404/404 [==============================] - 0s - loss: nan
# Epoch 8/300
# ...

# %% [markdown]
# d- con tamaño de batch 100
# --

# %%
model = Sequential()
model.add(Dense(200, input_dim=X_train_scaled.shape[1], init='uniform'))
model.add(Activation('relu'))
model.add(Dense(1, init='uniform'))
model.add(Activation('linear'))

model.compile(optimizer=sgd, loss='mean_squared_error')

model.fit(X_train_scaled.as_matrix(),y_train_scaled.as_matrix(),batch_size=100,nb_epoch=300)
# Out:
# /Users/ricardocarrasco/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(200, kernel_initializer="uniform", input_dim=14)`
#   from ipykernel import kernelapp as app
# /Users/ricardocarrasco/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:4: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(1, kernel_initializer="uniform")`
# Epoch 1/300
# 404/404 [==============================] - 0s - loss: 391.1711
# Epoch 2/300
# 404/404 [==============================] - 0s - loss: 199.6218
# Epoch 3/300
# 404/404 [==============================] - 0s - loss: nan
# Epoch 4/300
# 404/404 [==============================] - 0s - loss: nan
# Epoch 5/300
# 404/404 [==============================] - 0s - loss: nan
# Epoch 6/300
# 404/404 [==============================] - 0s - loss: nan
# Epoch 7/300
# 404/404 [==============================] - 0s - loss: nan
# Epoch 8/300
# ...

# %% [markdown]
# Diverge muy rápidamente.

# %% [markdown]
# j)
# --

# %%
from keras.optimizers import SGD, Adam, RMSprop, Adagrad, Adadelta

# %%
moptimizer =Adagrad(lr=0.01)
model = Sequential()
model.add(Dense(200, input_dim=X_train_scaled.shape[1], init='uniform'))
model.add(Activation('sigmoid'))
model.add(Dense(1, init='uniform'))
model.add(Activation('linear'))

model.compile(optimizer=moptimizer, loss='mean_squared_error')
hist = model.fit(X_train_scaled.as_matrix(), y_train_scaled.as_matrix(), nb_epoch=300, verbose=1, validation_data=(X_test_scaled.as_matrix(), y_test_scaled.as_matrix()))
# Out:
# /Users/ricardocarrasco/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:3: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(200, kernel_initializer="uniform", input_dim=14)`
#   app.launch_new_instance()
# /Users/ricardocarrasco/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:5: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(1, kernel_initializer="uniform")`
# Train on 404 samples, validate on 102 samples
# Epoch 1/300
# 404/404 [==============================] - 0s - loss: 452.5285 - val_loss: 341.0705
# Epoch 2/300
# 404/404 [==============================] - 0s - loss: 301.3950 - val_loss: 249.4009
# Epoch 3/300
# 404/404 [==============================] - 0s - loss: 219.8611 - val_loss: 193.4206
# Epoch 4/300
# 404/404 [==============================] - 0s - loss: 167.2330 - val_loss: 155.5235
# Epoch 5/300
# 404/404 [==============================] - 0s - loss: 130.8900 - val_loss: 128.3023
# Epoch 6/300
# ...

# %%
print(min(hist.history['loss']))
plt.xlabel("Epoch")
plt.ylabel("MSE")
plt.plot(hist.epoch, hist.history['loss'])
plt.grid(True)
plt.show()
# Out:
# 2.85866554893

# %% [markdown]
# Usando Adagrad la velocidad de convergencia es muy lenta, lo cual produce un resultado peor que usando SGD

# %%
moptimizer =Adam(lr=0.01)
model = Sequential()
model.add(Dense(200, input_dim=X_train_scaled.shape[1], init='uniform'))
model.add(Activation('sigmoid'))
model.add(Dense(1, init='uniform'))
model.add(Activation('linear'))

model.compile(optimizer=moptimizer, loss='mean_squared_error')
hist = model.fit(X_train_scaled.as_matrix(), y_train_scaled.as_matrix(), nb_epoch=300, verbose=1, validation_data=(X_test_scaled.as_matrix(), y_test_scaled.as_matrix()))
# Out:
# /Users/ricardocarrasco/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:3: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(200, kernel_initializer="uniform", input_dim=14)`
#   app.launch_new_instance()
# /Users/ricardocarrasco/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:5: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(1, kernel_initializer="uniform")`
# Train on 404 samples, validate on 102 samples
# Epoch 1/300
# 404/404 [==============================] - 0s - loss: 360.2227 - val_loss: 141.6442
# Epoch 2/300
# 404/404 [==============================] - 0s - loss: 63.4852 - val_loss: 52.9068
# Epoch 3/300
# 404/404 [==============================] - 0s - loss: 26.4613 - val_loss: 26.3531
# Epoch 4/300
# 404/404 [==============================] - 0s - loss: 16.2299 - val_loss: 17.7922
# Epoch 5/300
# 404/404 [==============================] - 0s - loss: 11.5975 - val_loss: 14.9935
# Epoch 6/300
# ...

# %%
print(min(hist.history['loss']))
plt.xlabel("Epoch")
plt.ylabel("MSE")
plt.plot(hist.epoch, hist.history['loss'])
plt.grid(True)
plt.show()
# Out:
# 0.0383193432031

# %% [markdown]
# Posee una convergencia inicialmente muy rápida, sin embargo en las últimas pruebas se vuelve más lento. De todas formas se obtiene un resultado mejor que en c.

# %%
moptimizer =RMSprop(lr=0.01)
model = Sequential()
model.add(Dense(200, input_dim=X_train_scaled.shape[1], init='uniform'))
model.add(Activation('sigmoid'))
model.add(Dense(1, init='uniform'))
model.add(Activation('linear'))

model.compile(optimizer=moptimizer, loss='mean_squared_error')
hist = model.fit(X_train_scaled.as_matrix(), y_train_scaled.as_matrix(), nb_epoch=300, verbose=1, validation_data=(X_test_scaled.as_matrix(), y_test_scaled.as_matrix()))
# Out:
# /Users/ricardocarrasco/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:3: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(200, kernel_initializer="uniform", input_dim=14)`
#   app.launch_new_instance()
# /Users/ricardocarrasco/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:5: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(1, kernel_initializer="uniform")`
# Train on 404 samples, validate on 102 samples
# Epoch 1/300
# 404/404 [==============================] - 0s - loss: 244.3489 - val_loss: 68.8278
# Epoch 2/300
# 404/404 [==============================] - 0s - loss: 30.1453 - val_loss: 26.2969
# Epoch 3/300
# 404/404 [==============================] - 0s - loss: 14.6176 - val_loss: 19.4585
# Epoch 4/300
# 404/404 [==============================] - 0s - loss: 11.2655 - val_loss: 12.5920
# Epoch 5/300
# 404/404 [==============================] - 0s - loss: 8.8804 - val_loss: 9.5912
# Epoch 6/300
# ...

# %%
print(min(hist.history['loss']))
plt.xlabel("Epoch")
plt.ylabel("MSE")
plt.plot(hist.epoch, hist.history['loss'])
plt.grid(True)
plt.show()
# Out:
# 0.112512029265

# %% [markdown]
# Al usar RMSprop la convergencia en las primeras iteraciones es rápida, sin embargo al llegar al valor de pérdida cercano a 1.000 no se obitnen mejores resultados, variando entre 0.500 y 1.500

# %%
moptimizer =Adadelta(lr=0.01)
model = Sequential()
model.add(Dense(200, input_dim=X_train_scaled.shape[1], init='uniform'))
model.add(Activation('sigmoid'))
model.add(Dense(1, init='uniform'))
model.add(Activation('linear'))

model.compile(optimizer=moptimizer, loss='mean_squared_error')
hist = model.fit(X_train_scaled.as_matrix(), y_train_scaled.as_matrix(), nb_epoch=300, verbose=1, validation_data=(X_test_scaled.as_matrix(), y_test_scaled.as_matrix()))
# Out:
# /Users/ricardocarrasco/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:3: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(200, kernel_initializer="uniform", input_dim=14)`
#   app.launch_new_instance()
# /Users/ricardocarrasco/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:5: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(1, kernel_initializer="uniform")`
# Train on 404 samples, validate on 102 samples
# Epoch 1/300
# 404/404 [==============================] - 0s - loss: 598.9820 - val_loss: 577.4289
# Epoch 2/300
# 404/404 [==============================] - 0s - loss: 598.6988 - val_loss: 577.1484
# Epoch 3/300
# 404/404 [==============================] - 0s - loss: 598.4079 - val_loss: 576.8634
# Epoch 4/300
# 404/404 [==============================] - 0s - loss: 598.1134 - val_loss: 576.5745
# Epoch 5/300
# 404/404 [==============================] - 0s - loss: 597.8147 - val_loss: 576.2803
# Epoch 6/300
# ...

# %%
print(min(hist.history['loss']))
plt.xlabel("Epoch")
plt.ylabel("MSE")
plt.plot(hist.epoch, hist.history['loss'])
plt.grid(True)
plt.show()
# Out:
# 429.972392167

# %% [markdown]
# La convergencia al usar Adadelta es extremadamente lenta, haciendo que el resultado sea el menos óptimo obtenido.

# %%
moptimizer =Adagrad(lr=0.01)
model = Sequential()
model.add(Dense(200, input_dim=X_train_scaled.shape[1], init='uniform'))
model.add(Activation('relu'))
model.add(Dense(1, init='uniform'))
model.add(Activation('linear'))

model.compile(optimizer=moptimizer, loss='mean_squared_error')
hist = model.fit(X_train_scaled.as_matrix(), y_train_scaled.as_matrix(), nb_epoch=300, verbose=1, validation_data=(X_test_scaled.as_matrix(), y_test_scaled.as_matrix()))
# Out:
# /Users/ricardocarrasco/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:3: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(200, kernel_initializer="uniform", input_dim=14)`
#   app.launch_new_instance()
# /Users/ricardocarrasco/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:5: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(1, kernel_initializer="uniform")`
# Train on 404 samples, validate on 102 samples
# Epoch 1/300
# 404/404 [==============================] - 0s - loss: 527.2855 - val_loss: 423.2508
# Epoch 2/300
# 404/404 [==============================] - 0s - loss: 347.3989 - val_loss: 276.3313
# Epoch 3/300
# 404/404 [==============================] - 0s - loss: 214.5229 - val_loss: 188.3109
# Epoch 4/300
# 404/404 [==============================] - 0s - loss: 139.8115 - val_loss: 138.3270
# Epoch 5/300
# 404/404 [==============================] - 0s - loss: 99.0086 - val_loss: 108.6978
# Epoch 6/300
# ...

# %%
print(min(hist.history['loss']))
plt.xlabel("Epoch")
plt.ylabel("MSE")
plt.plot(hist.epoch, hist.history['loss'])
plt.grid(True)
plt.show()
# Out:
# 0.8024947301

# %% [markdown]
# Usando Adagrad se observa una convergencia muy lenta, pero mejor que con Adadelta y una activacion sigmoid

# %%
moptimizer =Adam(lr=0.01)
model = Sequential()
model.add(Dense(200, input_dim=X_train_scaled.shape[1], init='uniform'))
model.add(Activation('relu'))
model.add(Dense(1, init='uniform'))
model.add(Activation('linear'))

model.compile(optimizer=moptimizer, loss='mean_squared_error')
hist = model.fit(X_train_scaled.as_matrix(), y_train_scaled.as_matrix(), nb_epoch=300, verbose=1, validation_data=(X_test_scaled.as_matrix(), y_test_scaled.as_matrix()))
# Out:
# /Users/ricardocarrasco/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:3: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(200, kernel_initializer="uniform", input_dim=14)`
#   app.launch_new_instance()
# /Users/ricardocarrasco/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:5: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(1, kernel_initializer="uniform")`
# Train on 404 samples, validate on 102 samples
# Epoch 1/300
# 404/404 [==============================] - 1s - loss: 464.2057 - val_loss: 225.7870
# Epoch 2/300
# 404/404 [==============================] - 0s - loss: 114.0929 - val_loss: 80.1347
# Epoch 3/300
# 404/404 [==============================] - 0s - loss: 34.0831 - val_loss: 39.6581
# Epoch 4/300
# 404/404 [==============================] - 0s - loss: 18.1692 - val_loss: 19.4193
# Epoch 5/300
# 404/404 [==============================] - 0s - loss: 11.5919 - val_loss: 14.7668
# Epoch 6/300
# ...

# %%
print(min(hist.history['loss']))
plt.xlabel("Epoch")
plt.ylabel("MSE")
plt.plot(hist.epoch, hist.history['loss'])
plt.grid(True)
plt.show()
# Out:
# 0.00948399480543

# %% [markdown]
# Usando Adam se logra apreciar una convergencia muy rápida, meyor que con sigmoidal, sin embargo en las últimas iteraciones el resultado comienza a diverger.

# %%
moptimizer =RMSprop(lr=0.01)
model = Sequential()
model.add(Dense(200, input_dim=X_train_scaled.shape[1], init='uniform'))
model.add(Activation('relu'))
model.add(Dense(1, init='uniform'))
model.add(Activation('linear'))

model.compile(optimizer=moptimizer, loss='mean_squared_error')
hist = model.fit(X_train_scaled.as_matrix(), y_train_scaled.as_matrix(), nb_epoch=300, verbose=1, validation_data=(X_test_scaled.as_matrix(), y_test_scaled.as_matrix()))
# Out:
# /Users/ricardocarrasco/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:3: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(200, kernel_initializer="uniform", input_dim=14)`
#   app.launch_new_instance()
# /Users/ricardocarrasco/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:5: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(1, kernel_initializer="uniform")`
# Train on 404 samples, validate on 102 samples
# Epoch 1/300
# 404/404 [==============================] - 0s - loss: 260.3624 - val_loss: 59.5349
# Epoch 2/300
# 404/404 [==============================] - 0s - loss: 25.7996 - val_loss: 30.0845
# Epoch 3/300
# 404/404 [==============================] - 0s - loss: 13.5800 - val_loss: 17.0494
# Epoch 4/300
# 404/404 [==============================] - 0s - loss: 9.5141 - val_loss: 8.9526
# Epoch 5/300
# 404/404 [==============================] - 0s - loss: 7.0964 - val_loss: 12.0258
# Epoch 6/300
# ...

# %%
print(min(hist.history['loss']))
plt.xlabel("Epoch")
plt.ylabel("MSE")
plt.plot(hist.epoch, hist.history['loss'])
plt.grid(True)
plt.show()
# Out:
# 0.071571219233

# %% [markdown]
# Usando RMSprop la convergencia es rápida en las primera iteraciones, sin embargo, al llegar al valor de pérdida de 1.00 aproximadamente comienza a inestabilizarse.

# %%
moptimizer =Adadelta(lr=0.01)
model = Sequential()
model.add(Dense(200, input_dim=X_train_scaled.shape[1], init='uniform'))
model.add(Activation('relu'))
model.add(Dense(1, init='uniform'))
model.add(Activation('linear'))

model.compile(optimizer=moptimizer, loss='mean_squared_error')
hist = model.fit(X_train_scaled.as_matrix(), y_train_scaled.as_matrix(), nb_epoch=300, verbose=1, validation_data=(X_test_scaled.as_matrix(), y_test_scaled.as_matrix()))
# Out:
# /Users/ricardocarrasco/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:3: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(200, kernel_initializer="uniform", input_dim=14)`
#   app.launch_new_instance()
# /Users/ricardocarrasco/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:5: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(1, kernel_initializer="uniform")`
# Train on 404 samples, validate on 102 samples
# Epoch 1/300
# 404/404 [==============================] - 1s - loss: 597.0972 - val_loss: 575.8563
# Epoch 2/300
# 404/404 [==============================] - 0s - loss: 597.0343 - val_loss: 575.7992
# Epoch 3/300
# 404/404 [==============================] - 0s - loss: 596.9710 - val_loss: 575.7413
# Epoch 4/300
# 404/404 [==============================] - 0s - loss: 596.9075 - val_loss: 575.6838
# Epoch 5/300
# 404/404 [==============================] - 0s - loss: 596.8436 - val_loss: 575.6256
# Epoch 6/300
# ...

# %%
print(min(hist.history['loss']))
plt.xlabel("Epoch")
plt.ylabel("MSE")
plt.plot(hist.epoch, hist.history['loss'])
plt.grid(True)
plt.show()
# Out:
# 115.921316695

# %% [markdown]
# Usando Adadelta no se observa una tasa de aprendizaje. El valor de pérdida es muy alto durante las 100 primeras iteraciones. Al final es cuando comienza a disminuir la pérdida, sin embargo, esta es muy alta.

# %% [markdown]
# k)
# --

# %% [markdown]
# Sigmoid
# --

# %% [markdown]
# l1(0.01)

# %%
from keras import regularizers
model = Sequential()
idim = X_train_scaled.shape[1]
model.add(Dense(200,input_dim=idim,init='uniform',W_regularizer=regularizers.l1(0.01)))
model.add(Activation('sigmoid'))
model.add(Dense(1,init='uniform',W_regularizer=regularizers.l1(0.01)))
model.add(Activation('linear'))

model.compile(optimizer=sgd, loss='mean_squared_error')

hist = model.fit(X_train_scaled.as_matrix(), y_train_scaled.as_matrix(), nb_epoch=300, verbose=1, validation_data=(X_test_scaled.as_matrix(), y_test_scaled.as_matrix()))
# Out:
# /Users/ricardocarrasco/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:4: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(200, kernel_regularizer=<keras.reg..., kernel_initializer="uniform", input_dim=14)`
# /Users/ricardocarrasco/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:6: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(1, kernel_regularizer=<keras.reg..., kernel_initializer="uniform")`
# Train on 404 samples, validate on 102 samples
# Epoch 1/300
# 404/404 [==============================] - 0s - loss: 245.7061 - val_loss: 75.1085
# Epoch 2/300
# 404/404 [==============================] - 0s - loss: 28.8278 - val_loss: 15.1472
# Epoch 3/300
# 404/404 [==============================] - 0s - loss: 7.9655 - val_loss: 7.9738
# Epoch 4/300
# 404/404 [==============================] - 0s - loss: 6.4538 - val_loss: 7.6797
# Epoch 5/300
# 404/404 [==============================] - 0s - loss: 5.6586 - val_loss: 6.5316
# ...

# %% [markdown]
# l1(0.09)

# %%
model = Sequential()
idim = X_train_scaled.shape[1]
model.add(Dense(200,input_dim=idim,init='uniform',W_regularizer=regularizers.l1(0.09)))
model.add(Activation('sigmoid'))
model.add(Dense(1,init='uniform',W_regularizer=regularizers.l1(0.09)))
model.add(Activation('linear'))

model.compile(optimizer=sgd, loss='mean_squared_error')

hist = model.fit(X_train_scaled.as_matrix(), y_train_scaled.as_matrix(), nb_epoch=300, verbose=1, validation_data=(X_test_scaled.as_matrix(), y_test_scaled.as_matrix()))
# Out:
# /Users/ricardocarrasco/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:3: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(200, kernel_regularizer=<keras.reg..., kernel_initializer="uniform", input_dim=14)`
#   app.launch_new_instance()
# /Users/ricardocarrasco/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:5: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(1, kernel_regularizer=<keras.reg..., kernel_initializer="uniform")`
# Train on 404 samples, validate on 102 samples
# Epoch 1/300
# 404/404 [==============================] - 0s - loss: 296.9344 - val_loss: 87.9146
# Epoch 2/300
# 404/404 [==============================] - 0s - loss: 99.3327 - val_loss: 72.6043
# Epoch 3/300
# 404/404 [==============================] - 0s - loss: 66.5731 - val_loss: 58.6885
# Epoch 4/300
# 404/404 [==============================] - 0s - loss: 48.0254 - val_loss: 37.9502
# Epoch 5/300
# ...

# %% [markdown]
# l2(0.01)

# %%
model = Sequential()
idim = X_train_scaled.shape[1]
model.add(Dense(200,input_dim=idim,init='uniform',W_regularizer=regularizers.l2(0.01)))
model.add(Activation('sigmoid'))
model.add(Dense(1,init='uniform',W_regularizer=regularizers.l2(0.01)))
model.add(Activation('linear'))

model.compile(optimizer=sgd, loss='mean_squared_error')

hist = model.fit(X_train_scaled.as_matrix(), y_train_scaled.as_matrix(), nb_epoch=300, verbose=1, validation_data=(X_test_scaled.as_matrix(), y_test_scaled.as_matrix()))
# Out:
# /Users/ricardocarrasco/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:3: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(200, kernel_regularizer=<keras.reg..., kernel_initializer="uniform", input_dim=14)`
#   app.launch_new_instance()
# /Users/ricardocarrasco/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:5: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(1, kernel_regularizer=<keras.reg..., kernel_initializer="uniform")`
# Train on 404 samples, validate on 102 samples
# Epoch 1/300
# 404/404 [==============================] - 0s - loss: 337.6148 - val_loss: 33.2791
# Epoch 2/300
# 404/404 [==============================] - 0s - loss: 54.2106 - val_loss: 20.0814
# Epoch 3/300
# 404/404 [==============================] - 0s - loss: 18.6689 - val_loss: 10.8299
# Epoch 4/300
# 404/404 [==============================] - 0s - loss: 8.2753 - val_loss: 6.3458
# Epoch 5/300
# ...

# %% [markdown]
# l2(0.09)

# %%
model = Sequential()
idim = X_train_scaled.shape[1]
model.add(Dense(200,input_dim=idim,init='uniform',W_regularizer=regularizers.l2(0.09)))
model.add(Activation('sigmoid'))
model.add(Dense(1,init='uniform',W_regularizer=regularizers.l2(0.09)))
model.add(Activation('linear'))

model.compile(optimizer=sgd, loss='mean_squared_error')

hist = model.fit(X_train_scaled.as_matrix(), y_train_scaled.as_matrix(), nb_epoch=300, verbose=1, validation_data=(X_test_scaled.as_matrix(), y_test_scaled.as_matrix()))
# Out:
# /Users/ricardocarrasco/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:3: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(200, kernel_regularizer=<keras.reg..., kernel_initializer="uniform", input_dim=14)`
#   app.launch_new_instance()
# /Users/ricardocarrasco/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:5: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(1, kernel_regularizer=<keras.reg..., kernel_initializer="uniform")`
# Train on 404 samples, validate on 102 samples
# Epoch 1/300
# 404/404 [==============================] - 0s - loss: 359.1142 - val_loss: 130.9409
# Epoch 2/300
# 404/404 [==============================] - 0s - loss: 82.6987 - val_loss: 51.6712
# Epoch 3/300
# 404/404 [==============================] - 0s - loss: 37.4428 - val_loss: 31.8795
# Epoch 4/300
# 404/404 [==============================] - 0s - loss: 21.6730 - val_loss: 18.8036
# Epoch 5/300
# ...

# %% [markdown]
# Para la activación sigmoidal (c) se puede apreciar que tanto en el regularizador l1 y l2 tienen un comportamiento similar con los distintos parametros de regularización. Con un valor de 0.01 se tiene una convergencia mucho mayor que con el valor 0.09.

# %% [markdown]
# Relu
# --

# %% [markdown]
# l1(0.01)

# %%
model = Sequential()
idim = X_train_scaled.shape[1]
model.add(Dense(200,input_dim=idim,init='uniform',W_regularizer=regularizers.l1(0.01)))
model.add(Activation('relu'))
model.add(Dense(1,init='uniform',W_regularizer=regularizers.l1(0.01)))
model.add(Activation('linear'))

model.compile(optimizer=sgd, loss='mean_squared_error')

hist = model.fit(X_train_scaled.as_matrix(), y_train_scaled.as_matrix(), nb_epoch=300, verbose=1, validation_data=(X_test_scaled.as_matrix(), y_test_scaled.as_matrix()))
# Out:
# /Users/ricardocarrasco/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:3: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(200, kernel_regularizer=<keras.reg..., kernel_initializer="uniform", input_dim=14)`
#   app.launch_new_instance()
# /Users/ricardocarrasco/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:5: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(1, kernel_regularizer=<keras.reg..., kernel_initializer="uniform")`
# Train on 404 samples, validate on 102 samples
# Epoch 1/300
# 404/404 [==============================] - 0s - loss: 764152702287.9795 - val_loss: inf
# Epoch 2/300
# 404/404 [==============================] - 0s - loss: nan - val_loss: nan
# Epoch 3/300
# 404/404 [==============================] - 0s - loss: nan - val_loss: nan
# Epoch 4/300
# 404/404 [==============================] - 0s - loss: nan - val_loss: nan
# Epoch 5/300
# 404/404 [==============================] - 0s - loss: nan - val_loss: nan
# ...

# %% [markdown]
# l1(0.09)

# %%
model = Sequential()
idim = X_train_scaled.shape[1]
model.add(Dense(200,input_dim=idim,init='uniform',W_regularizer=regularizers.l1(0.09)))
model.add(Activation('relu'))
model.add(Dense(1,init='uniform',W_regularizer=regularizers.l1(0.09)))
model.add(Activation('linear'))

model.compile(optimizer=sgd, loss='mean_squared_error')

hist = model.fit(X_train_scaled.as_matrix(), y_train_scaled.as_matrix(), nb_epoch=300, verbose=1, validation_data=(X_test_scaled.as_matrix(), y_test_scaled.as_matrix()))
# Out:
# /Users/ricardocarrasco/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:3: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(200, kernel_regularizer=<keras.reg..., kernel_initializer="uniform", input_dim=14)`
#   app.launch_new_instance()
# /Users/ricardocarrasco/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:5: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(1, kernel_regularizer=<keras.reg..., kernel_initializer="uniform")`
# Train on 404 samples, validate on 102 samples
# Epoch 1/300
# 404/404 [==============================] - 0s - loss: 196.5987 - val_loss: 3999.9772
# Epoch 2/300
# 404/404 [==============================] - 0s - loss: nan - val_loss: nan
# Epoch 3/300
# 404/404 [==============================] - 0s - loss: nan - val_loss: nan
# Epoch 4/300
# 404/404 [==============================] - 0s - loss: nan - val_loss: nan
# Epoch 5/300
# 404/404 [==============================] - 0s - loss: nan - val_loss: nan
# ...

# %% [markdown]
# l2(0.01)

# %%
model = Sequential()
idim = X_train_scaled.shape[1]
model.add(Dense(200,input_dim=idim,init='uniform',W_regularizer=regularizers.l2(0.01)))
model.add(Activation('relu'))
model.add(Dense(1,init='uniform',W_regularizer=regularizers.l2(0.01)))
model.add(Activation('linear'))

model.compile(optimizer=sgd, loss='mean_squared_error')

hist = model.fit(X_train_scaled.as_matrix(), y_train_scaled.as_matrix(), nb_epoch=300, verbose=1, validation_data=(X_test_scaled.as_matrix(), y_test_scaled.as_matrix()))
# Out:
# /Users/ricardocarrasco/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:3: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(200, kernel_regularizer=<keras.reg..., kernel_initializer="uniform", input_dim=14)`
#   app.launch_new_instance()
# /Users/ricardocarrasco/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:5: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(1, kernel_regularizer=<keras.reg..., kernel_initializer="uniform")`
# Train on 404 samples, validate on 102 samples
# Epoch 1/300
# 404/404 [==============================] - 0s - loss: nan - val_loss: nan
# Epoch 2/300
# 404/404 [==============================] - 0s - loss: nan - val_loss: nan
# Epoch 3/300
# 404/404 [==============================] - 0s - loss: nan - val_loss: nan
# Epoch 4/300
# 404/404 [==============================] - 0s - loss: nan - val_loss: nan
# Epoch 5/300
# 404/404 [==============================] - 0s - loss: nan - val_loss: nan
# Epoch 6/300
# ...

# %% [markdown]
# l2(0.09)

# %%
model = Sequential()
idim = X_train_scaled.shape[1]
model.add(Dense(200,input_dim=idim,init='uniform',W_regularizer=regularizers.l2(0.09)))
model.add(Activation('relu'))
model.add(Dense(1,init='uniform',W_regularizer=regularizers.l2(0.09)))
model.add(Activation('linear'))

model.compile(optimizer=sgd, loss='mean_squared_error')

hist = model.fit(X_train_scaled.as_matrix(), y_train_scaled.as_matrix(), nb_epoch=300, verbose=1, validation_data=(X_test_scaled.as_matrix(), y_test_scaled.as_matrix()))
# Out:
# /Users/ricardocarrasco/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:3: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(200, kernel_regularizer=<keras.reg..., kernel_initializer="uniform", input_dim=14)`
#   app.launch_new_instance()
# /Users/ricardocarrasco/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:5: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(1, kernel_regularizer=<keras.reg..., kernel_initializer="uniform")`
# Train on 404 samples, validate on 102 samples
# Epoch 1/300
# 404/404 [==============================] - 0s - loss: nan - val_loss: nan
# Epoch 2/300
# 404/404 [==============================] - 0s - loss: nan - val_loss: nan
# Epoch 3/300
# 404/404 [==============================] - 0s - loss: nan - val_loss: nan
# Epoch 4/300
# 404/404 [==============================] - 0s - loss: nan - val_loss: nan
# Epoch 5/300
# 404/404 [==============================] - 0s - loss: nan - val_loss: nan
# Epoch 6/300
# ...

# %% [markdown]
# Se puede ver claramente que cualquier regularizador para una activación "relu" hace que el resultado diverga inmediatamente.

# %% [markdown]
# l)
# --

# %%
from keras.layers import Dropout
model = Sequential()
model.add(Dense(200, input_dim=X_train_scaled.shape[1], init='uniform'))
model.add(Activation('sigmoid'))
model.add(Dense(1, init='uniform'))
model.add(Activation('linear'))
model.add(Dropout(0.2))

sgd = SGD(lr=0.01)
model.compile(optimizer=sgd, loss='mean_squared_error')

hist = model.fit(X_train_scaled.as_matrix(), y_train_scaled.as_matrix(), nb_epoch=300, verbose=1, validation_data=(X_test_scaled.as_matrix(), y_test_scaled.as_matrix()))
# Out:
# /Users/ricardocarrasco/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:3: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(200, kernel_initializer="uniform", input_dim=14)`
#   app.launch_new_instance()
# /Users/ricardocarrasco/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:5: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(1, kernel_initializer="uniform")`
# Train on 404 samples, validate on 102 samples
# Epoch 1/300
# 404/404 [==============================] - 0s - loss: 186.8801 - val_loss: 94.6751
# Epoch 2/300
# 404/404 [==============================] - 0s - loss: 142.6573 - val_loss: 43.1884
# Epoch 3/300
# 404/404 [==============================] - 0s - loss: 167.2364 - val_loss: 71.7343
# Epoch 4/300
# 404/404 [==============================] - 0s - loss: 136.6848 - val_loss: 48.1050
# Epoch 5/300
# 404/404 [==============================] - 0s - loss: 126.5248 - val_loss: 31.3059
# Epoch 6/300
# ...

# %% [markdown]
# Utilizando un valor de parámetro de regularización de Dropout con 0.2 y una activación sigmoid se puede ver que el valor no diverge, sin embargo tampoco converge, este se mantiene en una tasa de pérdida constante

# %%
model = Sequential()
model.add(Dense(200, input_dim=X_train_scaled.shape[1], init='uniform'))
model.add(Activation('relu'))
model.add(Dense(1, init='uniform'))
model.add(Activation('linear'))
model.add(Dropout(0.2))

sgd = SGD(lr=0.01)
model.compile(optimizer=sgd, loss='mean_squared_error')

hist = model.fit(X_train_scaled.as_matrix(), y_train_scaled.as_matrix(), nb_epoch=300, verbose=1, validation_data=(X_test_scaled.as_matrix(), y_test_scaled.as_matrix()))
# Out:
# /Users/ricardocarrasco/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(200, kernel_initializer="uniform", input_dim=14)`
#   from ipykernel import kernelapp as app
# /Users/ricardocarrasco/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:4: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(1, kernel_initializer="uniform")`
# Train on 404 samples, validate on 102 samples
# Epoch 1/300
# 404/404 [==============================] - 0s - loss: 289.1879 - val_loss: 46.9892
# Epoch 2/300
# 404/404 [==============================] - 0s - loss: 135.7042 - val_loss: 30.7021
# Epoch 3/300
# 404/404 [==============================] - 0s - loss: 127.8492 - val_loss: 37.6986
# Epoch 4/300
# 404/404 [==============================] - 0s - loss: 104.7501 - val_loss: 34.4799
# Epoch 5/300
# 404/404 [==============================] - 0s - loss: 113.2140 - val_loss: 30.6838
# Epoch 6/300
# ...

# %% [markdown]
# Al utilizar relu y los mismos parámetros anteriores el resultado es el mismo.

# %%
model = Sequential()
model.add(Dense(200, input_dim=X_train_scaled.shape[1], init='uniform'))
model.add(Activation('sigmoid'))
model.add(Dense(1, init='uniform'))
model.add(Activation('linear'))
model.add(Dropout(0.04))

sgd = SGD(lr=0.01)
model.compile(optimizer=sgd, loss='mean_squared_error')

hist = model.fit(X_train_scaled.as_matrix(), y_train_scaled.as_matrix(), nb_epoch=300, verbose=1, validation_data=(X_test_scaled.as_matrix(), y_test_scaled.as_matrix()))
# Out:
# /Users/ricardocarrasco/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(200, kernel_initializer="uniform", input_dim=14)`
#   from ipykernel import kernelapp as app
# /Users/ricardocarrasco/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:4: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(1, kernel_initializer="uniform")`
# Train on 404 samples, validate on 102 samples
# Epoch 1/300
# 404/404 [==============================] - 0s - loss: 122.6827 - val_loss: 46.7588
# Epoch 2/300
# 404/404 [==============================] - 0s - loss: 53.5114 - val_loss: 35.1988
# Epoch 3/300
# 404/404 [==============================] - 0s - loss: 43.9761 - val_loss: 31.4894
# Epoch 4/300
# 404/404 [==============================] - 0s - loss: 50.2489 - val_loss: 24.2186
# Epoch 5/300
# 404/404 [==============================] - 0s - loss: 31.5592 - val_loss: 20.3048
# Epoch 6/300
# ...

# %% [markdown]
# Al disminuir el valor del parámetro de regularización se puede ver una convergencia mucho mayor, sin embargo esta no mejora al punto c.
